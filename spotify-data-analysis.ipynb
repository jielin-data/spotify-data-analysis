# %% [markdown]
# # Popular Songs on Spotify for every year (2000-2023)
# ### 🎉Let's get started what song is must popular in Spotify every year!!

# %% [markdown]
# ## Section 1: Dataset 📉
#
# ### Dataset Overview
# I chose the "Spotify Best Songs on Spotify for Every Year(2000-2023)" dataset from Kaggle because of my passion for music and my desire to understand what makes a song successful. The dataset includes audio features such as danceability, energy, popularity, and more, for the most-streamed songs on Spotify. I enjoy discovering new music trends, and Spotify being a major music platform, offers a reflection of global listening habits. Through this dataset, I aim to explore which musical features—such as year, energy, and top-genre with a song's popularity.
#
# ##### Note: year=(The year the song was released)

# %%
import pandas as pd
Spotify=pd.read_csv('Dataset.csv', sep=";")
Spotify
# Out:
#                                        title               artist  \
# 0                                    Flowers          Miley Cyrus
# 1                          Cupid - Twin Ver.          FIFTY FIFTY
# 2                                       BESO              ROSALÍA
# 3                         Boy's a liar Pt. 2       PinkPantheress
# 4     Creepin' (with The Weeknd & 21 Savage)         Metro Boomin
# ...                                      ...                  ...
# 2380                              Southbound           Beach Blvd
# 2381     Dance with Somebody - Radio Version           Mando Diao
# 2382                                    Flow      Desire Machines
# 2383                      Scared of the Dark  Everything Brighter
# 2384                                   Sorry                LEADR
#
#              top genre  year  bpm  energy  danceability  dB  liveness  \
# 0                  pop  2023  118      68            71  -4         3
# ...

# %%
len(Spotify.columns)
# Out:
# 14

# %% [markdown]
# This code is describe the dataset have 14 columns.

# %%
len(Spotify)
# Out:
# 2385

# %% [markdown]
# This code is describe the dataset have 2385 rows.

# %%
Spotify.head(10)
# Out:
#                                     title          artist  \
# 0                                 Flowers     Miley Cyrus
# 1                       Cupid - Twin Ver.     FIFTY FIFTY
# 2                                    BESO         ROSALÍA
# 3                      Boy's a liar Pt. 2  PinkPantheress
# 4  Creepin' (with The Weeknd & 21 Savage)    Metro Boomin
# 5                                Daylight   David Kushner
# 6                                     TQG         KAROL G
# 7           Calm Down (with Selena Gomez)            Rema
# 8                               Anti-Hero    Taylor Swift
# 9                            Here With Me            d4vd
#
#                  top genre  year  bpm  energy  danceability  dB  liveness  \
# 0                      pop  2023  118      68            71  -4         3
# 1         k-pop girl group  2023  120      59            78  -8        35
# 2                      pop  2023   95      64            77  -7        17
# ...

# %% [markdown]
# This code is describe the first ten rows of dataset.

# %% [markdown]
# ## Section 2: Exploratory Data Analysis 📑
#
# ### Let's pick four columns to find out which type of "top genre" is the most popular and so on...
#
# Part 1️⃣. First, you need select other three columns you like, but 'popularity' is required. (such as "artist", "top genre", "year", "popularity") Remember, there must be four columns in total.
#
# Part 2️⃣. Second, you need to find out which genre is liked by most people.
#
# Part 3️⃣. Then, you need to find out which energy number best reflects the spirit and vitality of a song.
#
# Part 4️⃣. You need find out which year has the most songs in this dataset.
#
# Part 5️⃣. Finally, you need to find which year has the highest average popularity.

# %% [markdown]
# ## Part 1
# ### 🎈Pick the four columns your interest! 🎈

# %%
Spotify4=Spotify[["top genre", "energy","year","popularity"]]
Spotify4
# Out:
#              top genre  energy  year  popularity
# 0                  pop      68  2023          98
# 1     k-pop girl group      59  2023          97
# 2                  pop      64  2023          96
# 3          bronx drill      81  2023          96
# 4                  rap      62  2022          96
# ...                ...     ...   ...         ...
# 2380              rock      88  2023          21
# 2381     dalarna indie      90  2009          16
# 2382             indie      87  2022          15
# 2383               pop      80  2023          11
# 2384    tropical house      64  2023           5
#
# [2385 rows x 4 columns]

# %% [markdown]
# These descriptive statistics can help me get an overview of the data. For example, I chose Top Music Genres, Energy, Year, and Popularity. These columns can help people understand what music people like to listen to and which genres are the most popular.

# %% [markdown]
# ## Part 2
# ### ❓Which top genre is popular❓

# %%
topMus=Spotify["top genre"].value_counts().reset_index().nlargest(1,"count")
topMus
# Out:
#    top genre  count
# 0  dance pop    460

# %% [markdown]
# This code is finding out which type of top genre is the most popular, which also shows which type of music people like to listen to the most.

# %% [markdown]
# ## Part 3
# ### ❕Top energy❕

# %%
Energy= Spotify["energy"].value_counts().reset_index().nlargest(1,"count")
Energy
# Out:
#    energy  count
# 0      80     73

# %% [markdown]
# This code finds out what the score is for a listener's apparent preference for high-energy music.

# %% [markdown]
# ## Part 4
# ### ✌️Which year's songs do most people listen to?✌️

# %%
Year=Spotify["year"].value_counts().reset_index().nlargest(1,"count")
Year
# Out:
#    year  count
# 0  2012    126

# %% [markdown]
# This code represents songs released in 2012 that are being played at the maximum number of listeners. The year 2012 appears most frequently in the dataset because it occurs 126 times.

# %% [markdown]
# ## Part 5
# ### 🤔Identifying the year with the highest average song popularity🤔

# %%
Spotify4PerYear=Spotify4[["year", "popularity"]].groupby("year").agg("mean",numeric_only=True).reset_index()
Spotify4PerYear.nlargest(1,"popularity")
# Out:
#    year  popularity
# 0  1985        86.0

# %% [markdown]
# The code calculates the year with the highest average song popularity. The result indicates that songs released in 1985 had the highest average popularity, meaning they were the most played by listeners.

# %% [markdown]
# ### Data Analysis
# In this dataset, I aimed to identify which factors are related to popularity on Spotify in 2000 to 2023. First, I analyzed the columns top genre, energy, and year to understand the musical preferences of listeners. Second, I determined the most frequently occurring genre is dance pop in the dataset, this show the type of music people like to listen. Third, I discovered that listeners prefer high-energy songs, as the highest energy value (80) appeared 73 times, more frequently than other energy levels. Fourth, I found that the most common release year among popular songs was 2012, suggesting that listeners enjoy music from that year. Finally, I observed that songs released in 1985 had the highest average popularity, indicating that people also enjoy listening to older music.

# %% [markdown]
# ## Section 3: Exploratory Data Visualization ✍️
#
# ### Let's combined popularity score and energy score, find out does high-energy songs tend to be more popular on Spotify? Use scatter plot to finger out!

# %%
Spotify["combined_score"] = Spotify["popularity"] + Spotify["energy"]
top_songs = Spotify.nlargest(2385, "combined_score")
top_songs.plot.scatter(x = "energy",y = "popularity",title="The songs have higher popularity and energy",figsize=(40,10))
# Out:
# <Axes: title={'center': 'The songs have higher popularity and energy'}, xlabel='energy', ylabel='popularity'>

# %%
top_songs
# Out:
#                      title               artist           top genre  year  \
# 10         I'm Good (Blue)         David Guetta            big room  2022
# 164            Promiscuous        Nelly Furtado      canadian latin  2006
# 189   Empire State Of Mind                JAY-Z  east coast hip hop  2009
# 256                Hey Ya!              Outkast         atl hip hop  2003
# 292   Timber (feat. Ke$ha)              Pitbull           dance pop  2012
# ...                    ...                  ...                 ...   ...
# 2361      The Selfish Gene         Marlon Percy                 pop  2022
# 2323               Be Here  Sweet Imperfections         alternative  2023
# 2344          Up The Score           Trill Ryan           viral rap  2023
# 2384                 Sorry                LEADR      tropical house  2023
# 2373            Lost Souls              KJ Hand               indie  2022
#
#       bpm  energy  danceability  dB  liveness  valence  duration  \
# ...

# %% [markdown]
# This scatter plot analyzes the whole 2385 songs  based on their combined energy and popularity scores, plotting energy on the x-axis and popularity on the y-axis. The visualization reveals that while most data points  are concentrated on the middle and right-hand side, energy levels between 60-90. However, their popularity distribution shows significant vertical dispersion, indicating only a weak correlation between these variables. Notably, many high-energy songs have low popularity(likely niche genres) and some low-energy songs have higher popularity. However, there are still a few points in the upper right corner that have both high energy and high popularity. This shows how musical popularity depends on multiple factors beyond just energy, including genre conventions and audience preferences. In addition, I also found out that their highest combine score is 191, and the song is called I'm good (Blue) by David Guetta.

# %% [markdown]
# # Section 4: Planning for Part II 🔔
#
# 1. In my exploratory analysis of the dataset, I identified several interesting trends in music preferences in 2000 to 2023. First, regarding genre distribution, "dance pop" emerged as the most popular genre, with 460 occurrences, indicating a clear preference for pop music with dance rhythms. Further analysis of the music characteristics revealed that songs with an energy value of 80 appear most frequently, highlighting a strong market preference for high-energy songs. This trend is also evident in the chronological distribution: songs released in 2010 lead the list with 126 occurrences, while songs from 1985 with an average popularity score of 86. This shows that people are drawn to listening to older songs. Finally, I found that a high energy level doesn't necessarily correlate with popularity.
#
# 2. In the second part of the project, I would like to analyze and explore specific questions are "Which audio features are most connected with popularity?" Additionally, I plan to investigate what happens in the energy ranges between 40-50 and 75-85. I will also  wanna know the differences that might exist between the two dominant music genres (pop songs vs. dance pop songs). Finally, I want to compare the dance pop to other top genres.

# %% [markdown]
# ## Section 5: Data Science 🧑‍🔬
# The problem I decided to focus on was analyzing the difference in popularity between songs in the 40-50 and 75-85 energy ranges. I chose this because I think it’s interesting to see how the energy of a song might affect how popular it is. To start, I’ll use Python to split the songs into two groups based on their energy levels. One group will have songs with energy levels between 40 and 50, and the other group will have songs with energy levels between 75 and 85. After that, I’ll perform a z-test(hypothesis test) to check if the difference in popularity between the two groups is statistically significant. I picked this problem because it has clear data, and the smaller energy ranges make it easier to analyze and understand.

# %% [markdown]
# ## Part 6: Song Counts by Energy Ranges (40–50 & 75–85)
#
# #### ➡️ Set the varbile call **“low_energy”** and **“high_energy”** to find out the answer

# %%
import pandas as pd
Spotify=pd.read_csv('Dataset.csv', sep=";")
low_energy = Spotify[(Spotify["energy"] >= 40) & (Spotify["energy"] <= 50)] 
low_energy
# Out:
#                                   title         artist  \
# 5                              Daylight  David Kushner
# 9                          Here With Me           d4vd
# 26                      Search & Rescue          Drake
# 29            Unholy (feat. Kim Petras)      Sam Smith
# 30    All Of The Girls You Loved Before   Taylor Swift
# ...                                 ...            ...
# 2273                        Magic Stick       Lil' Kim
# 2278                      Tunnel Vision    Kodak Black
# 2301                               Gone         *NSYNC
# 2322                        Slow Motion     Trey Songz
# 2361                   The Selfish Gene   Marlon Percy
#
#                     top genre  year  bpm  energy  danceability  dB  liveness  \
# 5     gen z singer-songwriter  2023  130      43            51  -9         9
# 9                 bedroom pop  2022  132      47            57  -8        13
# ...

# %% [markdown]
# This code is used there are 191 songs with energy score equal to or less than 40 and less than or equal to 50.

# %%
import pandas as pd
Spotify=pd.read_csv('Dataset.csv', sep=";")
high_energy=high_energy = Spotify[(Spotify["energy"] >= 75) & (Spotify["energy"] <= 85)] 
high_energy
# Out:
#                                      title               artist  \
# 3                       Boy's a liar Pt. 2       PinkPantheress
# 7            Calm Down (with Selena Gomez)                 Rema
# 13                         I Ain't Worried          OneRepublic
# 14    Quevedo: Bzrp Music Sessions Vol. 52             Bizarrap
# 28                         Sweater Weather    The Neighbourhood
# ...                                    ...                  ...
# 2367                             Funky Man          Charlie Mat
# 2370                 Save Your Heart First                 KTEE
# 2376            Pop Ya Collar - Radio Edit                Usher
# 2377                         Lead You Afar    Jordan Cabo Smith
# 2383                    Scared of the Dark  Everything Brighter
#
#                     top genre  year  bpm  energy  danceability  dB  liveness  \
# 3                 bronx drill  2023  133      81            70  -8        25
# ...

# %% [markdown]
# This code is used there are 580 songs with energy score equal to or less than 75 and less than or equal to 85.

# %% [markdown]
# ## Part 7：Total Songs in Selected Energy Ranges
#
# ### Find the total number of songs with energy scores falling in either the 40–50 or 75–85 range
#
# ### ➡️To create a DataFrame containing low and high energy scores and create the varible call "df_score"

# %%
df_score = pd.DataFrame({
    "40-50 energy song": low_energy["popularity"],
    "75-85 energy song": high_energy["popularity"],
})
df_score
# Out:
#       40-50 energy song  75-85 energy song
# 3                   NaN               96.0
# 5                  96.0                NaN
# 7                   NaN               95.0
# 9                  94.0                NaN
# 13                  NaN               93.0
# ...                 ...                ...
# 2367                NaN               29.0
# 2370                NaN               28.0
# 2376                NaN               24.0
# 2377                NaN               23.0
# 2383                NaN               11.0
#
# [771 rows x 2 columns]

# %% [markdown]
# This code shows that there are 771 songs in total with energy scores between 40–50 and 75–85.

# %% [markdown]
# ## Part 8：Defining Our Hypotheses
# ### ➡️Define the null and alternative hypotheses below.

# %% [markdown]
# The null hypothesis states that there is no difference in the mean popularity between low-energy and high-energy songs, the mean **(H0):low-energy songs = high-energy songs**. The alternative hypothesis is that low-energy songs are more popular on average than high-energy songs,so it is **(H1):low-energy songs > high-energy songs**.

# %% [markdown]
# ## Part 9:
# ### Find the average popularity of low energy and high energy
#
# #### ➡️ Set up the varible call **low_mean** and **high_mean** and find out their average popularity

# %%
low_mean=low_energy["popularity"].mean()
low_mean
# Out:
# np.float64(72.48167539267016)

# %% [markdown]
# This code is find out what is the average popularity of low energy song.

# %%
high_mean=high_energy["popularity"].mean()
high_mean
# Out:
# np.float64(69.97413793103448)

# %% [markdown]
# This code is find out what is the average popularity of high energy song.

# %% [markdown]
# ## Part 10：Conducting the Hypothesis Test
# ### Find out z-test and p-value between energy score 40-50 and 75-85.

# %%
from statsmodels.stats.weightstats import ztest
test=ztest(low_energy['popularity'], high_energy['popularity'], alternative='larger')
test
# Out:
# (np.float64(2.6939209601996055), np.float64(0.0035308454303702628))

# %% [markdown]
# This code is find out the z-test and p-value. Also, find out the  Z-test is 2.769 and P- value is smaller than 0.05, so we  reject the null hypothesis，low-energy songs are significantly more popular than high-energy songs (p < 0.05). The large Z-score and tiny p-value confirm this difference is statistically reliable.

# %% [markdown]
# # Section 6: A Different Data Visualization 📊
# ### Use box.plot to finger out the different between those two energy score(40-50)&(75-85)!

# %%
df_score.plot.box(xlabel=('Different Between Two Energy Score (40-50)&(75-85)'),ylabel=('Popularity Score (0-100)'),title=('Popularity Distribution by Energy Level'))
# Out:
# <Axes: title={'center': 'Popularity Distribution by Energy Level'}, xlabel='Different Between Two Energy Score (40-50)&(75-85)', ylabel='Popularity Score (0-100)'>

# %% [markdown]
# This box plot shows the distribution of song popularity scores (ranging from 0 to 100) across different energy levels (40–50 and 75–85). Overall, songs in the 40–50 energy range tend to have higher and more concentrated popularity scores, with a median around 73 and less fluctuation(less dots below the box). In contrast, songs in the 75–85 energy range have a slightly lower median, around 70, and show more fluctuation(more dots below the box). This suggests that 75–85 energy songs have a greater range in popularity, with some low-score outliers. Statistical analysis further supports this observation: the result (Z = 2.69, p = 0.0035), this means we can rejection of the null hypothesis, indicating that low-energy songs are significantly more popular than high-energy songs (p < 0.05). The large Z-value and small p-value confirm that this difference is statistically significant. Overall, songs with lower energy levels seem to have slightly higher and more stable popularity. Also, 40-50 energy songs Q1 is around 62 and Q3 is about 80; 75-85 energy songs Q1 is around 61 and Q3 is about 79.

# %% [markdown]
# # Section 7: Overall Summary ✅

# %% [markdown]
# One of my data science projects was about analyze the “Spotify Songs of the Year (2000–2023)” dataset from Kaggle to explore which musical features are linked to song popularity, driven by my interest in music trends. The dataset includes 2,385 of Spotify’s most popular songs, along with various audio features such as danceability, energy, and popularity scores. I first summarized the statistics for popular genres, energy levels, and release years. The results show that Dance Pop is the most common genre, appearing 460 times, reflecting a strong market preference for rhythmic, fast-paced music. When looking at energy, songs with an energy value of 80 showed up most frequently (73 times), suggesting that listeners generally gravitate toward high-energy tracks. As for release years, 2010 saw the highest number of songs (126). Also, songs from 1985 though fewer in number and they had the highest average popularity score (86), this mean many people like to listen the old songs.Finally, I identified the highest-scoring song, “I'm Good (Blue)” by David Guetta, with a combined energy score and popularity score is equal 191(most highest one).
#
# For a deeper analysis of the relationship between energy and popularity, I created a scatter plot comparing the two. The data showed that most songs had energy values clustered between 60 and 90, but the popularity scores were spread out vertically, suggesting only a weak positive correlation between energy and popularity. To dig deeper, I performed a hypothesis test by selecting two groups: songs with energy values between 40–50 (low-energy group) and songs between 75–85 (high-energy group). I calculated the average popularity for each group and found that low-energy songs had an average popularity score of 72.49, while high-energy songs averaged around 70. A Z-test (Z = 2.69, p = 0.0035) confirmed that low-energy songs were significantly more popular than high-energy songs, with the difference being statistically significant (p < 0.05). A box plot supported this conclusion, showing that low-energy songs had a higher median popularity and a more centralized distribution, while high-energy songs showed greater fluctuation in popularity. In summary, this project not only deepened my understanding of how music preferences relate to factors like energy but also allowed me to apply exploratory data analysis, hypothesis testing, and data visualization to highlight the key elements that influence song popularity.
